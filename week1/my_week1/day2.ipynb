# %%
import requests
from dotenv import load_dotenv
from openai import OpenAI



requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
from openai import OpenAI
from scraper import fetch_website_contents
from IPython.display import Markdown , display

OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama= OpenAI(base_url=OLLAMA_BASE_URL, api_key="ollama")

def messages_for_website(website):
  system_prompt = """ You are a helpful assistant that summarizes the content of the website provided by the user. Provide a concise summary that captures the main points and key information from the website avoid content related to navigtion. Return only and only markdown formatted text."""
  user_prompt = f""" Here is the content of the website: {website}"""
  messages = [ { "role": "system", "content": system_prompt },
              { "role": "user", "content": user_prompt },
           ] 
  return messages

def summarize(url):
  website=fetch_website_contents(url)
  response=ollama.chat.completions.create(
  model="llama3.2:1b",
  messages= messages_for_website(website)
  )
  return response.choices[0].message.content

display(Markdown(summarize("https://edwarddonner.com")))
# Out:
# The capital of France is Paris.

# %%
import tiktoken

# %%
encoding=tiktoken.encoding_for_model("gemini-2.5-flash-lite")
print(encoding.encode("Hello, how are you?"))
token = encoding.encode("Hello, how are you?")
print(len(token))
